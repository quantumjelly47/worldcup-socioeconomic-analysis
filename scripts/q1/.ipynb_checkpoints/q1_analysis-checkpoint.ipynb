# %%
# Load libraries
import numpy as np
import pandas as pd
import matplotlib as plt
import seaborn as sns

# %%
# Import merged world cup and socioeconomic data
data = pd.read_csv("../../data/created_datasets/world_cup/merge_wc_with_socioeconomic.csv")
a = 2
